# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import classification_report, confusion_matrix
# %matplotlib inline

col_names = ['ID', 'RI', 'NA2O', 'MGO', 'AL2O3', 'SIO2', 'K2O', 'CAO', 'BAO', 'FE2O3', 'TYPE']
dataset = pd.read_csv("https://archive.ics.uci.edu/ml/machine-learning-databases/glass/glass.data", header=None, names=col_names)
dataset.shape
dataset.head()
# Out:
#    ID       RI   NA2O   MGO  AL2O3   SIO2   K2O   CAO  BAO  FE2O3  TYPE
# 0   1  1.52101  13.64  4.49   1.10  71.78  0.06  8.75  0.0    0.0     1
# 1   2  1.51761  13.89  3.60   1.36  72.73  0.48  7.83  0.0    0.0     1
# 2   3  1.51618  13.53  3.55   1.54  72.99  0.39  7.78  0.0    0.0     1
# 3   4  1.51766  13.21  3.69   1.29  72.61  0.57  8.22  0.0    0.0     1
# 4   5  1.51742  13.27  3.62   1.24  73.08  0.55  8.07  0.0    0.0     1

# %%
X = dataset.drop('TYPE', axis=1)
X = X.drop('ID', axis=1)
y = dataset['TYPE']
print(X)
# Out:
# RI   NA2O   MGO  AL2O3   SIO2   K2O   CAO   BAO  FE2O3
# 0    1.52101  13.64  4.49   1.10  71.78  0.06  8.75  0.00    0.0
# 1    1.51761  13.89  3.60   1.36  72.73  0.48  7.83  0.00    0.0
# 2    1.51618  13.53  3.55   1.54  72.99  0.39  7.78  0.00    0.0
# 3    1.51766  13.21  3.69   1.29  72.61  0.57  8.22  0.00    0.0
# 4    1.51742  13.27  3.62   1.24  73.08  0.55  8.07  0.00    0.0
# ..       ...    ...   ...    ...    ...   ...   ...   ...    ...
# 209  1.51623  14.14  0.00   2.88  72.61  0.08  9.18  1.06    0.0
# 210  1.51685  14.92  0.00   1.99  73.06  0.00  8.40  1.59    0.0
# 211  1.52065  14.36  0.00   2.02  73.42  0.00  8.44  1.64    0.0
# 212  1.51651  14.38  0.00   1.94  73.61  0.00  8.48  1.57    0.0
# 213  1.51711  14.23  0.00   2.08  73.36  0.00  8.62  1.67    0.0
#
# [214 rows x 9 columns]

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.50)

# %%
classifier = DecisionTreeClassifier(max_depth=3)
classifier.fit(X_train, y_train)
y_pred = classifier.predict(X_test)

# %%
print(confusion_matrix(y_test, y_pred))
print(classification_report(y_test, y_pred))
# Out:
# [[31  5  0  0  0  1]
#  [10 25  0  1  0  0]
#  [ 8  3  0  0  0  0]
#  [ 0  2  0  4  0  0]
#  [ 0  2  0  0  0  0]
#  [ 0  1  0  1  0 13]]
#               precision    recall  f1-score   support
#
#            1       0.63      0.84      0.72        37
#            2       0.66      0.69      0.68        36
#            3       0.00      0.00      0.00        11
#            5       0.67      0.67      0.67         6
#            6       0.00      0.00      0.00         2
#            7       0.93      0.87      0.90        15
#
#     accuracy                           0.68       107
#    macro avg       0.48      0.51      0.49       107
# weighted avg       0.61      0.68      0.64       107

# %%
plt.plot(dataset)
plt.show()

# %%
plt.plot(X_train)
plt.plot(y_pred)
plt.plot(y_train)
plt.show()
